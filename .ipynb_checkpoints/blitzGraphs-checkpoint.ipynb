# %%
# IMPORT PACKAGES
import matplotlib.pyplot as plt
import pandas as pd

# %%
# IMPORT CSVs 
years = [18, 19, 20, 21, 22, 23]
data = []

abvs = ['ARI', 'ATL', 'BAL', 'BUF', 'CAR', 'CHI', 'CIN', 'CLE', 'DAL', 
        'DEN', 'DET', 'GB', 'HOU', 'IND', 'JAX', 'KC', 'LV', 'LAC', 
        'LAR', 'MIA', 'MIN', 'NE', 'NO', 'NYG', 'NYJ', 'PHI', 
        'PIT', 'SEA', 'SF', 'TB', 'TEN', 'WAS']

for year in years:
    file_name = "Data/advPass" + str(year) + ".csv"
    data.append(pd.read_csv(file_name))

# ADD IN ABVs
for x in data:
    x.insert(1, "Abv", abvs, True)

# %%
#VERIFY CSV IMPORTS

for x in data:
    print(x.head())
# Out:
#                   Tm  Abv   G  Att  Cmp   Yds  TD  DADOT   Air   YAC  Bltz  \
# 0  Arizona Cardinals  ARI  16  506  342  3262  21    7.1  1773  1799   222
# 1    Atlanta Falcons  ATL  16  585  398  4153  33    8.2  2380  1934   139
# 2   Baltimore Ravens  BAL  16  577  337  3360  21    8.3  2020  1684   252
# 3      Buffalo Bills  BUF  16  492  313  2867  22    7.2  1553  1482   128
# 4  Carolina Panthers  CAR  16  529  353  3847  32    8.7  2354  1695   198
#
#    Bltz%  Hrry  Hrry%  QBKD QBKD%  Sk  Prss  Prss%  MTkl
# 0  38.5%    68  11.8%    38  7.5%  49   155  26.9%   124
# 1  21.5%    70  10.8%    30  5.1%  37   137  21.2%   112
# 2  39.6%    94  14.8%    47  8.1%  43   184  28.9%   105
# 3  23.4%    76  13.9%    41  8.3%  36   153  28.0%   137
# 4  33.4%    68  11.5%    25  4.7%  35   128  21.6%   104
#                   Tm  Abv   G  Att  Cmp   Yds  TD  DADOT   Air   YAC  Bltz  \
# 0  Arizona Cardinals  ARI  16  601  421  4510  38    7.5  2471  2228   267
# 1    Atlanta Falcons  ATL  16  536  351  3918  28    8.0  2134  1924   145
# 2   Baltimore Ravens  BAL  16  544  318  3315  15    8.8  1929  1650   329
# 3      Buffalo Bills  BUF  16  553  348  3123  15    7.1  1921  1668   191
# 4  Carolina Panthers  CAR  16  544  347  3696  21    9.1  2210  1711   167
#
#    Bltz%  Hrry Hrry%  QBKD  QBKD%  Sk  Prss  Prss%  MTkl
# 0  39.7%    52  7.7%    44   7.3%  40   136  20.2%   135
# 1  24.5%    52  8.8%    29   5.4%  28   109  18.4%    95
# 2  54.9%    44  7.3%    59  10.8%  37   140  23.4%    93
# 3  31.1%    58  9.4%    41   7.4%  44   143  23.3%   132
# 4  26.9%    57  9.2%    46   8.5%  53   156  25.2%   109
#                   Tm  Abv   G  Att  Cmp   Yds  TD  DADOT   Air   YAC  Bltz  \
# 0  Arizona Cardinals  ARI  16  570  365  3623  26    7.7  1884  2039   257
# 1    Atlanta Falcons  ATL  16  625  425  4697  34    8.3  2651  2207   225
# 2   Baltimore Ravens  BAL  16  596  380  3536  22    7.7  2245  1943   290
#
#    Bltz%  Hrry Hrry%  QBKD  QBKD%  Sk  Prss  Prss%  MTkl
# 0  22.5%    42  7.3%    23   4.5%  33    98  17.1%    73
# 1  23.9%    49  7.9%    52   9.5%  42   143  23.0%    95
# 2  21.9%    28  3.8%    55   8.7%  60   143  19.5%    92
# 3  23.5%    45  6.9%    59  10.7%  54   158  24.4%   101
# 4  28.5%    18  3.4%    45   9.4%  27    90  17.2%   131

# %%
# CREATE GRAPHS w/ POINTS

cur_data = data[0]

# DEFINE FUNCTION 

def grapher(cur_data, year):
    for i, label in enumerate(cur_data['Abv']):
        plt.annotate(label, (cur_data['Bltz%'][i], cur_data['Sk'][i]), textcoords="offset points", xytext=(0,10), ha='center')

    cur_data = cur_data.sort_values(by='Bltz%')

    if year < 22:
        row_index = cur_data[cur_data['Abv'] == 'BAL'].index[0]
        colors = ['blue' if label != 'BAL' else 'red' for label in cur_data['Abv']]
    else:
        row_index = cur_data[cur_data['Abv'] == 'NYG'].index[0]
        colors = ['blue' if label != 'NYG' else 'red' for label in cur_data['Abv']]

    plt.scatter(cur_data['Bltz%'], cur_data['Sk'], color=colors)

    # Add labels and title
    plt.xlabel('Blitz Rate')
    plt.ylabel('Sacks')
    plt.title('Blitz Rate vs Sack 20' + str(year))

    plt.xticks(range(1, 32, 6))

    # Add line for median num of league sacks and line for num of Wink sacks respectively
    plt.axhline(cur_data['Sk'].median(), color='blue', linestyle='--', linewidth=2)
    plt.axhline(cur_data.at[row_index, 'Sk'], color='red', linestyle='--', linewidth=2)

    # Add legend
    plt.legend()

    # Show plot
    plt.grid(True)
    plt.show()

# %%
# CREATE GRAPHS

for x in range(len(data)):
    grapher(data[x], years[x])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# CREATE GRAPH w/o POINTS
# TODO: Fix this 

cur_data = data[0]
cur_data = cur_data.sort_values(by='Bltz%')

# Create a scatter plot without markers
for index, row in cur_data.iterrows():
    plt.text(row['Bltz%'], row['Sk'], row['Abv'], fontsize=12, ha='center', va='center')

# Add labels and title
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Scatter Plot with Labels Only')

plt.grid(True)
plt.show()

# %%
# FIND CORRELATIONS B/W BLTZ% & SKs

bltz_percent = []

for x in range(len(data)):
    cur_data = data[x]
    bltz_percent.append(cur_data['Bltz%'].str.replace('%', ''))

for i in range(len(bltz_percent)):
    for j in range(len(bltz_percent[i])):
        bltz_percent[i][j] = float(bltz_percent[i][j])
    

for x in range(len(data)):
    cur_data = data[x]
    print("The correlation b/w BLTZ% and SKs in 20" + str(years[x]) + " is " + str(bltz_percent[x].corr(cur_data['Sk'])))
# Out:
# The correlation b/w BLTZ% and SKs in 2018 is 0.18104377708635822
# The correlation b/w BLTZ% and SKs in 2019 is 0.1678191052254649
# The correlation b/w BLTZ% and SKs in 2020 is 0.2908726176299426
# The correlation b/w BLTZ% and SKs in 2021 is 0.27019556191600713
# The correlation b/w BLTZ% and SKs in 2022 is -0.051130895264602884
# The correlation b/w BLTZ% and SKs in 2023 is -0.18735197856795616
