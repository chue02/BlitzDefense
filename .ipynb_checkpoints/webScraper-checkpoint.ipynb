# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# Webscrape tm defensive stats from years 18-23
# ProFootballReference only lets you webscrape the first couple of tables in a given page as
# it uses JavaScript to limit how much of a page a bot can access.

years = [18, 19, 20, 21, 22, 23]

for year in years:
    url = "https://www.pro-football-reference.com/years/20" + str(year) + "/opp.htm"
    df = pd.read_html(url, header = [0,1])[0]

    df.to_csv("def" + str(year) + ".csv")

#print(df.head())

'''
# https://stmorse.github.io/journal/pfr-scrape-python.html

scrapedPage = requests.get("https://www.pro-footballf-reference.com/teams/nyg/2020.htm")

soup = BeautifulSoup(scrapedPage.text, "lxml")

teamStats = soup.find("table", id="team_stats")

statType = []
for x in teamStats.find_all("th"):
    title = x.text
    statType.append(x)

print(statType)
'''

'''
https://www.sports-reference.com/bot-traffic.html
https://stackoverflow.com/questions/63385657/scraping-a-team-stats-table-from-python-using-bs4
https://www.youtube.com/watch?v=XNhOs2bVHMo
https://stackoverflow.com/questions/48217969/scraping-pfr-football-data-with-python-for-a-beginner
'''
# Out:
#   Unnamed: 0_level_0    Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                   Rk                    Tm                  G
# 0                1.0     Minnesota Vikings               16.0
# 1                2.0  Jacksonville Jaguars               16.0
# 2                3.0  Los Angeles Chargers               16.0
# 3                4.0   Philadelphia Eagles               16.0
# 4                5.0  New England Patriots               16.0
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Tot Yds & TO             \
#                   PA                Yds          Ply  Y/P    TO
# 0              252.0             4415.0        956.0  4.6  19.0
# 1              268.0             4578.0        993.0  4.6  33.0
# 2              272.0             5254.0        997.0  5.3  27.0
# 3              295.0             4904.0        976.0  5.0  31.0
# 4              296.0             5856.0       1022.0  5.7  18.0
#
#   Unnamed: 8_level_0 Unnamed: 9_level_0  ... Rushing                   \
#                   FL               1stD  ...     Yds    TD  Y/A  1stD
# 0                5.0              260.0  ...  1337.0  10.0  3.7  59.0
# 1               12.0              257.0  ...  1860.0   9.0  4.3  91.0
# 2                9.0              282.0  ...  2098.0  11.0  4.9  99.0
# 3               12.0              272.0  ...  1267.0   7.0  3.8  62.0
# 4                6.0              325.0  ...  1836.0   6.0  4.7  98.0
#
#   Penalties               Unnamed: 25_level_0 Unnamed: 26_level_0  \
#         Pen     Yds 1stPy                 Sc%                 TO%
# 0     105.0   928.0  33.0                27.9                10.1
# 1     112.0  1050.0  23.0                23.9                15.6
# 2     109.0   996.0  30.0                28.5                15.1
# 3     101.0   917.0  33.0                27.1                15.4
# 4     111.0  1035.0  23.0                30.2                 9.9
#
#   Unnamed: 27_level_0
#                   EXP
# 0              145.07
# 1              252.15
# 2              120.25
# 3              162.09
# 4               12.09
#
# [5 rows x 28 columns]
# '\nhttps://www.sports-reference.com/bot-traffic.html\nhttps://stackoverflow.com/questions/63385657/scraping-a-team-stats-table-from-python-using-bs4\nhttps://www.youtube.com/watch?v=XNhOs2bVHMo\nhttps://stackoverflow.com/questions/48217969/scraping-pfr-football-data-with-python-for-a-beginner\n'

# %%
print(df.head())
print(df.iloc[:,3])
# Out:
#   Unnamed: 0_level_0    Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                   Rk                    Tm                  G
# 0                1.0     Minnesota Vikings               16.0
# 1                2.0  Jacksonville Jaguars               16.0
# 2                3.0  Los Angeles Chargers               16.0
# 3                4.0   Philadelphia Eagles               16.0
# 4                5.0  New England Patriots               16.0
#
#   Unnamed: 3_level_0 Unnamed: 4_level_0 Tot Yds & TO             \
#                   PA                Yds          Ply  Y/P    TO
# 0              252.0             4415.0        956.0  4.6  19.0
# 1              268.0             4578.0        993.0  4.6  33.0
# 2              272.0             5254.0        997.0  5.3  27.0
# 3              295.0             4904.0        976.0  5.0  31.0
# 4              296.0             5856.0       1022.0  5.7  18.0
#
#   Unnamed: 8_level_0 Unnamed: 9_level_0  ... Rushing                   \
#                   FL               1stD  ...     Yds    TD  Y/A  1stD
# 0                5.0              260.0  ...  1337.0  10.0  3.7  59.0
# 1               12.0              257.0  ...  1860.0   9.0  4.3  91.0
# 2                9.0              282.0  ...  2098.0  11.0  4.9  99.0
# 3               12.0              272.0  ...  1267.0   7.0  3.8  62.0
# 4                6.0              325.0  ...  1836.0   6.0  4.7  98.0
#
#   Penalties               Unnamed: 25_level_0 Unnamed: 26_level_0  \
#         Pen     Yds 1stPy                 Sc%                 TO%
# 0     105.0   928.0  33.0                27.9                10.1
# 1     112.0  1050.0  23.0                23.9                15.6
# 2     109.0   996.0  30.0                28.5                15.1
# 3     101.0   917.0  33.0                27.1                15.4
# 4     111.0  1035.0  23.0                30.2                 9.9
#
#   Unnamed: 27_level_0
#                   EXP
# 0              145.07
# 1              252.15
# 2              120.25
# 3              162.09
# 4               12.09
#
# [5 rows x 28 columns]
# 0       252.0
# 1       268.0
# 2       272.0
# 3       295.0
# 4       296.0
# 5       303.0
# 6       308.0
# 7       315.0
# 8       320.0
# 9       326.0
# 10      327.0
# 11      329.0
# 12      332.0
# 13      332.0
# 14      339.0
# 15      349.0
# 16      356.0
# 17      359.0
# 18      361.0
# 19      373.0
# 20      376.0
# 21      382.0
# 22      382.0
# 23      382.0
# 24      383.0
# 25      384.0
# 26      388.0
# 27      388.0
# 28      393.0
# 29      404.0
# 30      410.0
# 31      436.0
# 32      347.5
# 33    11120.0
# 34       21.7
# Name: (Unnamed: 3_level_0, PA), dtype: float64
